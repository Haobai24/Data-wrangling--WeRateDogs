# %% [markdown]
# ## WeRateDogs action report
#
# ### Introduction
# In Data wrangling, 3 steps were performed to clean the datasets that contain tweets on people’s dogs with its rating, image and comments, etc. The data is then explorex and analyzed. For data wrangling process, please refer to wrangle_act file for steps and codes.
#
# ### Insights
# - Insight 1. Most favorite dog tweets: Sort the twitter dataframe according to order start from the highest favorite counts. The top 3 tweet urls received the most counts are shared as below
#
# Top 1. https://twitter.com/dog_rates/status/744234799360020481
#
# Top 2. https://twitter.com/dog_rates/status/822872901745569793
#
# Top 3. https://twitter.com/dog_rates/status/807106840509214720
#
#
# - Insight 2. Retweet counts vs Favorite counts: Visualization was created to study the relationship between retweet counts with favorite counts. The plot clearly showed a positive correlations.
# ![image.png](attachment:image.png)
# Plot 1: Retweet Counts Vs. Favorite Counts

# %% [markdown]
# - Insight 3. Dog breed and stage counts: Pie chart was created to visualize the portions on each dog stages. It is interesting to see pupper counted as 68.03% among all dog stages. It seems young dogs are more popular or people tend to take photos when the dogs are younger.
# ![image.png](attachment:image.png)
# plot 2: Dog Stages porportions.

# %% [markdown]
# In the second plot on dog predictions, golden retriever breed has the most predictions, and therefore is the most popular breed. The next three breeds also received high numbers compare to the rest predictions, which are labrador retriever, pembroke and chihuahua. These breeds do make sense as they are seen more often in real life.
# ￼![image.png](attachment:image.png)
# plot 3: Top 10 dog predictions.
#
#
# ### Conclustion:
# Thanks to WeRateDogs twitter account for providing the dataset. Many interesting facts were found to study our human’s best friends. Real data often doesn’t come clean. It is necessary to perform steps to clean the data gathered in order to provide readable and accurate results, then the data is ready to be explored to provide information and answer questions.
